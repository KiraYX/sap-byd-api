# %%
import pandas as pd
import warnings
from IPython.display import HTML

# Suppress specific UserWarning from Pandas
warnings.filterwarnings("ignore", category=UserWarning, message="Data Validation extension is not supported")

# Read the BOM sheet with header in row 2
file_path = "../data/bom275.xlsx"
sheet_name = "BOM"
df_bom = pd.read_excel(file_path, sheet_name=sheet_name, header=1)


# Drop rows where all cells are NaN
df_bom = df_bom.dropna(how="all")
# Drop columns where all values are NaN
df_bom = df_bom.dropna(axis=1, how="all")


# Display the total number of rows and columns
print("Total rows and columns:", df_bom.shape)

# Replace 'ColumnName' with the actual name of the column up to which you want to keep
last_column_to_keep = "备注"

# List all column names
column_names = df_bom.columns.tolist()
# print(column_names)

# Specify the columns you want to keep
columns_to_keep = ['所属装配体', '布局号', 'PLM编号', '层级深度', '父层级', '整套总数', 'ERP编号', '物料描述', '单层数量', '单位', '物料种类']

# Select only these columns
df_bom = df_bom[columns_to_keep]

html_table = df_bom.to_html(index=False)

display(HTML(html_table))
# Out:
# Total rows and columns: (826, 39)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>所属装配体</th>
#       <th>布局号</th>
#       <th>PLM编号</th>
#       <th>层级深度</th>
#       <th>父层级</th>
#       <th>整套总数</th>
#       <th>ERP编号</th>
#       <th>物料描述</th>
#       <th>单层数量</th>
#       <th>单位</th>
#       <th>物料种类</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Flipper翻转机构</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4</td>
#       <td>10014229</td>
#       <td>Flipper_MJFG_A275-01-1000-0-A</td>
#       <td>4.00</td>
#       <td>EA - 个</td>
#       <td>产成品</td>
#     </tr>
#     <tr>
#       <td>Flipper翻转机构</td>
#       <td>1.0</td>
#       <td>1.1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>MCP-275-WPF.1</td>
#       <td>Frame_MJSF_G275-01-1100-0-A</td>
#       <td>1.00</td>
#       <td>EA - 个</td>
#       <td>装配体</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.1</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>4</td>
#       <td>10014619</td>
#       <td>WD Frame_MJRM_P275-01-1101-0-A</td>
#       <td>1.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.2</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>16</td>
#       <td>10014591</td>
#       <td>经济型 重载调整块_MISUMI_E-LWAL01-D80-M20-L150</td>
#       <td>4.00</td>
#       <td>EA - 个</td>
#       <td>外购件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.3</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10014618</td>
#       <td>SM Support_MJRM_P275-01-1102-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.4</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10014617</td>
#       <td>SM Support_MJRM_P275-01-1103-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.5</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10014616</td>
#       <td>SM Shell_MJRM_P275-01-1104-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.6</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10014615</td>
#       <td>SM Shell_MJRM_P275-01-1105-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.7</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>72</td>
#       <td>MCP-275-WPF.1</td>
#       <td>固万基 10.9级镀锌圆头内六角带垫螺丝_JD_M5x10</td>
#       <td>18.00</td>
#       <td>EA - 个</td>
#       <td>外购件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.8</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>64</td>
#       <td>螺丝耗材区</td>
#       <td>鹏驰 12.9级杯头内六角镀镍螺丝_Taobao_M8x20</td>
#       <td>16.00</td>
#       <td>EA - 个</td>
#       <td>外购件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.9</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10003614</td>
#       <td>负公差定位销_YESMRO_H-MSH6-12</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>外购件</td>
#     </tr>
#     <tr>
#       <td>机架</td>
#       <td>1.0</td>
#       <td>1.1.10</td>
#       <td>2</td>
#       <td>1.1</td>
#       <td>8</td>
#       <td>10008196</td>
#       <td>负公差定位销_YESMRO_H-MSH8-15</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>外购件</td>
#     </tr>
#     <tr>
#       <td>Flipper翻转机构</td>
#       <td>1.0</td>
#       <td>1.2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>MCP-275-WPF.1</td>
#       <td>Conveyor Module_MJSF_G275-01-1200-0-A</td>
#       <td>1.00</td>
#       <td>EA - 个</td>
#       <td>装配体</td>
#     </tr>
#     <tr>
#       <td>输送模组</td>
#       <td>1.0</td>
#       <td>1.2.1</td>
#       <td>2</td>
#       <td>1.2</td>
#       <td>4</td>
#       <td>MCP-275-WPF.1</td>
#       <td>Conveyor Base Plate_MJSF_G275-01-1210-0-A</td>
#       <td>1.00</td>
#       <td>EA - 个</td>
#       <td>装配体</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.1</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>4</td>
#       <td>10014747</td>
#       <td>MP Plate_MJRM_P275-01-1236-0-A</td>
#       <td>1.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.2</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014746</td>
#       <td>MP Strip_MJRM_P275-01-1238-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.3</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>48</td>
#       <td>10014745</td>
#       <td>MP Strip_MJRM_P275-01-1240-0-A</td>
#       <td>12.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.4</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014595</td>
#       <td>MP Plate_MJRM_P275-01-1420-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.5</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014744</td>
#       <td>MP Strip_MJRM_P275-01-1239-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.6</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>12</td>
#       <td>10014743</td>
#       <td>MP Strip_MJRM_P275-01-1242-0-A</td>
#       <td>3.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.7</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014742</td>
#       <td>MP Strip_MJRM_P275-01-1244-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.8</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014741</td>
#       <td>MP Block_MJRM_P275-01-1245-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.9</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>16</td>
#       <td>10014740</td>
#       <td>MP Block_MJRM_P275-01-1246-0-A</td>
#       <td>4.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.10</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014739</td>
#       <td>MP Block_MJRM_P275-01-1247-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.11</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>16</td>
#       <td>10014738</td>
#       <td>MP Plate_MJRM_P275-01-1248-0-A</td>
#       <td>4.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.12</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014737</td>
#       <td>MP Block_MJRM_P275-01-1249-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.13</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014736</td>
#       <td>MP Block_MJRM_P275-01-1259-0-A</td>
#       <td>2.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.14</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>16</td>
#       <td>10014735</td>
#       <td>MP Block_MJRM_P275-01-1260-0-A</td>
#       <td>4.00</td>
#       <td>EA - 个</td>
#       <td>加工件</td>
#     </tr>
#     <tr>
#       <td>输送模组基座板</td>
#       <td>1.0</td>
#       <td>1.2.1.15</td>
#       <td>3</td>
#       <td>1.2.1</td>
#       <td>8</td>
#       <td>10014620</td>
#       <td>导向轴支座_MIS
